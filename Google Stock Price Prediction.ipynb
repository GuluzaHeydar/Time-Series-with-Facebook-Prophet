# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>What is Colaboratory?</h1>
#
# Colaboratory, or "Colab" for short, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to GPUs
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!

# %% [markdown]
# ## **Getting started**
#
# The document you are reading is not a static web page, but an interactive environment called a **Colab notebook** that lets you write and execute code.
#
# For example, here is a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut "Command/Ctrl+Enter". To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine **executable code** and **rich text** in a single document, along with **images**, **HTML**, **LaTeX** and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To learn more, see [Overview of Colab](/notebooks/basic_features_overview.ipynb). To create a new Colab notebook you can use the File menu above, or use the following link: [create a new Colab notebook](http://colab.research.google.com#create=true).
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To learn more about the Jupyter project, see [jupyter.org](https://www.jupyter.org).

# %% [markdown]
# ## Data science
#
# With Colab you can harness the full power of popular Python libraries to analyze and visualize data. The code cell below uses **numpy** to generate some random data, and uses **matplotlib** to visualize it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from Github and many other sources. To learn more about importing data, and how Colab can be used for data science, see the links below under [Working with Data](#working-with-data).

# %% [markdown]
# ## Machine learning
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just [a few lines of code](https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb). Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including [GPUs and TPUs](#using-accelerated-hardware), regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the [machine learning examples](#machine-learning-examples) below.

# %% [markdown]
# ## More Resources
#
# ### Working with Notebooks in Colab
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/master/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
# - <img src="/img/new.png" height="20px" align="left" hspace="4px" alt="New"></img>
#  [TensorFlow 2 in Colab](/notebooks/tensorflow_version.ipynb)
#
# <a name="working-with-data"></a>
# ### Working with Data
# - [Loading data: Drive, Sheets, and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualizing data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# ### Machine Learning Crash Course
# These are a few of the notebooks from Google's online Machine Learning course. See the [full course website](https://developers.google.com/machine-learning/crash-course/) for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
#
# <a name="using-accelerated-hardware"></a>
# ### Using Accelerated Hardware
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <a name="machine-learning-examples"></a>
#
# ## Machine Learning Examples
#
# To see end-to-end examples of the interactive machine learning analyses that Colaboratory makes possible, check out these  tutorials using models from [TensorFlow Hub](https://tfhub.dev).
#
# A few featured examples:
#
# - [Retraining an Image Classifier](https://tensorflow.org/hub/tutorials/tf2_image_retraining): Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - [Text Classification](https://tensorflow.org/hub/tutorials/tf2_text_classification): Classify IMDB movie reviews as either *positive* or *negative*.
# - [Style Transfer](https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization): Use deep learning to transfer style between images.
# - [Multilingual Universal Sentence Encoder Q&A](https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa): Use a machine learning model to answer questions from the SQuAD dataset.
# - [Video Interpolation](https://tensorflow.org/hub/tutorials/tweening_conv3d): Predict what happened in a video between the first and the last frame.

# %%
from fbprophet import Prophet
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1c525edc-be4d-4279-b60b-fd694b9223f9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c525edc-be4d-4279-b60b-fd694b9223f9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving google-data.csv to google-data (1).csv

# %%
data = pd.read_csv("google-data.csv")

# %%
data.head()
# Out:
#          Date        Open        High  ...       Close   Adj Close   Volume
# 0  2013-01-02  357.385559  361.151062  ...  359.288177  359.288177  5115500
# 1  2013-01-03  360.122742  363.600128  ...  359.496826  359.496826  4666500
# 2  2013-01-04  362.313507  368.339294  ...  366.600616  366.600616  5562800
# 3  2013-01-07  365.348755  367.301056  ...  365.001007  365.001007  3332900
# 4  2013-01-08  365.393463  365.771027  ...  364.280701  364.280701  3373900
#
# [5 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   object
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 69.0+ KB

# %%
data.Date = data.Date.apply(pd.to_datetime)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1259 non-null   datetime64[ns]
#  1   Open       1259 non-null   float64
#  2   High       1259 non-null   float64
#  3   Low        1259 non-null   float64
#  4   Close      1259 non-null   float64
#  5   Adj Close  1259 non-null   float64
#  6   Volume     1259 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB

# %%
a = data[["Date","Close"]]
a.columns = ["ds", "y"]

# %%
a
# Out:
#              ds            y
# 0    2013-01-02   359.288177
# 1    2013-01-03   359.496826
# 2    2013-01-04   366.600616
# 3    2013-01-07   365.001007
# 4    2013-01-08   364.280701
# ...         ...          ...
# 1254 2017-12-22  1060.119995
# 1255 2017-12-26  1056.739990
# 1256 2017-12-27  1049.369995
# 1257 2017-12-28  1048.140015
# 1258 2017-12-29  1046.400024
#
# [1259 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(x= a.ds, y= a.y)
plt.show()

# %%
train = a.iloc[:-100,]
test = a.iloc[-100:]

# %%
model = Prophet()

# %%
model.fit(train)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast = model.make_future_dataframe(periods = 100, freq= "D")
predictions = model.predict(forecast)

# %%
forecast.shape
# Out:
# (1259, 1)

# %%
predictions.head()
# Out:
#           ds       trend  ...  multiplicative_terms_upper        yhat
# 0 2013-01-02  386.997704  ...                         0.0  372.251039
# 1 2013-01-03  387.169039  ...                         0.0  370.875693
# 2 2013-01-04  387.340375  ...                         0.0  370.795412
# 3 2013-01-07  387.854382  ...                         0.0  369.718749
# 4 2013-01-08  388.025718  ...                         0.0  369.778760
#
# [5 rows x 19 columns]

# %%
preds = predictions[["ds", "yhat"]]

# %%
model.plot(predictions, xlabel = "Date", ylabel= "Stock_close_price");

# %%
model.plot_components(predictions)

# %%
preds.shape
# Out:
# (1259, 2)

# %%
y_pred = preds.iloc[-100:, 1]
y_test = test.y

# %%
y_pred
# Out:
# 1159     976.612423
# 1160     975.564497
# 1161     975.723284
# 1162     953.721062
# 1163     953.514837
#            ...
# 1254     983.563052
# 1255    1004.381091
# 1256    1003.835059
# 1257    1003.725988
# 1258    1002.018702
# Name: yhat, Length: 100, dtype: float64

# %%
y_test
# Out:
# 1159     922.900024
# 1160     907.239990
# 1161     914.390015
# 1162     922.669983
# 1163     922.219971
#            ...
# 1254    1060.119995
# 1255    1056.739990
# 1256    1049.369995
# 1257    1048.140015
# 1258    1046.400024
# Name: y, Length: 100, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
def rmse(y_t, y_p):
  return float(np.sqrt(mean_squared_error(y_true= y_test, y_pred= y_pred)))

# %%
rmse(y_test, y_pred)
# Out:
# 44.31477243427674

# %%
a.shape
# Out:
# (1259, 2)

# %%
# !pip install --quiet optuna

# %%
import optuna
from fbprophet.diagnostics import cross_validation, performance_metrics

# %%
m = Prophet()
m.fit(a) 

number_initial_days = 366

a_cv = cross_validation(m,
                         initial=f'{number_initial_days} days', 
                         period='180 days', 
                         horizon = '100 days',
                         parallel='processes')

a_p = performance_metrics(a_cv)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Making 8 forecasts with cutoffs between 2014-04-09 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39efb3c50>

# %%
param_types = {'changepoint_prior_scale': 'float', 
               'seasonality_prior_scale': 'float',
               'holidays_prior_scale': 'float',
              'seasonality_mode': 'int'}

bounds = {'changepoint_prior_scale': [0.001, 0.5],
          'seasonality_prior_scale': [0.01, 10],
          'holidays_prior_scale': [0.01, 8],
          'seasonality_mode': [0, 1]}

# %%
def objective(trial):
    '''Train prophet model and return rmse'''
    params = {}
    for param in ['changepoint_prior_scale', 'seasonality_prior_scale','holidays_prior_scale']:
        params[param] = trial.suggest_uniform(param, bounds[param][0], bounds[param][1])
        
    stationality = ['additive', 'multiplicative']
    params['seasonality_mode'] = stationality[trial.suggest_int('seasonality_mode', 
                                                                  bounds['seasonality_mode'][0], 
                                                                  bounds['seasonality_mode'][1])]

    m = Prophet(weekly_seasonality=True,
                daily_seasonality=False,
                **params)
    
    m.fit(a) 
    number_initial_days = 500
    df_cv = cross_validation(m, 
                             initial=f'{number_initial_days} days', 
                             period='180 days', 
                         horizon = '100 days',
                         parallel='processes')
    
    df_p = performance_metrics(df_cv, rolling_window=1)
    print(df_p['mape'].mean())
    
    return df_p['rmse'].values[0]

# %%
study = optuna.create_study()
study.optimize(objective, n_trials = 15)
# Out:
# [I 2021-10-23 17:35:01,781] A new study created in memory with name: no-name-53a38069-da7a-40d8-a739-f683b7aea2b1
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39ee64910>
# [I 2021-10-23 17:35:25,256] Trial 0 finished with value: 88.86492230515118 and parameters: {'changepoint_prior_scale': 0.13363760808885264, 'seasonality_prior_scale': 3.7224319866162228, 'holidays_prior_scale': 2.284730853561965, 'seasonality_mode': 0}. Best is trial 0 with value: 88.86492230515118.
# 0.10073380782152132
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39ef3ca10>
# [I 2021-10-23 17:36:03,619] Trial 1 finished with value: 134.37128220650223 and parameters: {'changepoint_prior_scale': 0.3380595327137604, 'seasonality_prior_scale': 7.508509526991994, 'holidays_prior_scale': 4.517928780882585, 'seasonality_mode': 1}. Best is trial 0 with value: 88.86492230515118.
# 0.14834319640119123
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39f1adc10>
# [I 2021-10-23 17:36:27,920] Trial 2 finished with value: 88.62731776244095 and parameters: {'changepoint_prior_scale': 0.13608937043246294, 'seasonality_prior_scale': 6.2920541732529935, 'holidays_prior_scale': 6.563843104306026, 'seasonality_mode': 0}. Best is trial 2 with value: 88.62731776244095.
# 0.09971339020861432
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39edb2690>
# [I 2021-10-23 17:37:03,208] Trial 3 finished with value: 137.12110090764105 and parameters: {'changepoint_prior_scale': 0.474848640142191, 'seasonality_prior_scale': 8.49924083402413, 'holidays_prior_scale': 6.927427555034321, 'seasonality_mode': 1}. Best is trial 2 with value: 88.62731776244095.
# 0.155547606236657
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39f262290>
# [I 2021-10-23 17:37:42,119] Trial 4 finished with value: 140.60399480114475 and parameters: {'changepoint_prior_scale': 0.45465726748728946, 'seasonality_prior_scale': 6.824061492320573, 'holidays_prior_scale': 5.859096847385993, 'seasonality_mode': 1}. Best is trial 2 with value: 88.62731776244095.
# 0.15606505170807275
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39eff30d0>
# [I 2021-10-23 17:38:22,379] Trial 5 finished with value: 134.75183325514166 and parameters: {'changepoint_prior_scale': 0.34704401418398284, 'seasonality_prior_scale': 3.5954362576306536, 'holidays_prior_scale': 3.6269417365714665, 'seasonality_mode': 1}. Best is trial 2 with value: 88.62731776244095.
# 0.15046322817701557
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd3a062b190>
# [I 2021-10-23 17:39:05,684] Trial 6 finished with value: 101.92647617021966 and parameters: {'changepoint_prior_scale': 0.06073729323976175, 'seasonality_prior_scale': 7.173147654949613, 'holidays_prior_scale': 5.278993765031067, 'seasonality_mode': 1}. Best is trial 2 with value: 88.62731776244095.
# 0.11470000341805395
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd3a3fb8810>
# [I 2021-10-23 17:39:50,547] Trial 7 finished with value: 116.67278851702038 and parameters: {'changepoint_prior_scale': 0.16784180160559936, 'seasonality_prior_scale': 6.886427447932063, 'holidays_prior_scale': 7.889320637218568, 'seasonality_mode': 1}. Best is trial 2 with value: 88.62731776244095.
# 0.12196471040635239
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39ef27650>
# [I 2021-10-23 17:40:29,492] Trial 8 finished with value: 130.34742389649992 and parameters: {'changepoint_prior_scale': 0.31841261530044057, 'seasonality_prior_scale': 6.579991519179777, 'holidays_prior_scale': 3.3213820585545193, 'seasonality_mode': 1}. Best is trial 2 with value: 88.62731776244095.
# 0.1430156870455248
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39f0f5e50>
# [I 2021-10-23 17:41:11,145] Trial 9 finished with value: 117.8599649889223 and parameters: {'changepoint_prior_scale': 0.16606399008834527, 'seasonality_prior_scale': 3.7073378125044565, 'holidays_prior_scale': 4.127383780165576, 'seasonality_mode': 1}. Best is trial 2 with value: 88.62731776244095.
# 0.11988977800772263
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39f4d61d0>
# [I 2021-10-23 17:41:26,675] Trial 10 finished with value: 83.5984159895225 and parameters: {'changepoint_prior_scale': 0.023918955875731188, 'seasonality_prior_scale': 0.5859449781399135, 'holidays_prior_scale': 0.15761433769072175, 'seasonality_mode': 0}. Best is trial 10 with value: 83.5984159895225.
# 0.09245082660814417
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39f59b150>
# [I 2021-10-23 17:41:39,024] Trial 11 finished with value: 93.05251742356451 and parameters: {'changepoint_prior_scale': 0.0022002362369776818, 'seasonality_prior_scale': 0.1513133617848465, 'holidays_prior_scale': 0.032029944022819556, 'seasonality_mode': 0}. Best is trial 10 with value: 83.5984159895225.
# 0.11429455970818798
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39f609a10>
# [I 2021-10-23 17:41:59,841] Trial 12 finished with value: 85.79625986733593 and parameters: {'changepoint_prior_scale': 0.08197595593329074, 'seasonality_prior_scale': 0.8642413412866601, 'holidays_prior_scale': 0.1370098544595379, 'seasonality_mode': 0}. Best is trial 10 with value: 83.5984159895225.
# 0.09873532429493842
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39f0f5e50>
# [I 2021-10-23 17:42:14,641] Trial 13 finished with value: 83.71756086038187 and parameters: {'changepoint_prior_scale': 0.023246003950939623, 'seasonality_prior_scale': 0.0462150651765274, 'holidays_prior_scale': 0.057239472968364055, 'seasonality_mode': 0}. Best is trial 10 with value: 83.5984159895225.
# 0.09109397659239339
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2014-10-06 00:00:00 and 2017-09-20 00:00:00
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fd39ee64910>
# [I 2021-10-23 17:42:27,632] Trial 14 finished with value: 89.21549280295525 and parameters: {'changepoint_prior_scale': 0.008789711278242168, 'seasonality_prior_scale': 1.682141111316203, 'holidays_prior_scale': 1.4638972874933347, 'seasonality_mode': 0}. Best is trial 10 with value: 83.5984159895225.
# 0.10852753651929624

# %%
study.best_params
# Out:
# {'changepoint_prior_scale': 0.023918955875731188,
#  'holidays_prior_scale': 0.15761433769072175,
#  'seasonality_mode': 0,
#  'seasonality_prior_scale': 0.5859449781399135}

# %%
train
# Out:
#              ds           y
# 0    2013-01-02  359.288177
# 1    2013-01-03  359.496826
# 2    2013-01-04  366.600616
# 3    2013-01-07  365.001007
# 4    2013-01-08  364.280701
# ...         ...         ...
# 1154 2017-08-02  930.390015
# 1155 2017-08-03  923.650024
# 1156 2017-08-04  927.960022
# 1157 2017-08-07  929.359985
# 1158 2017-08-08  926.789978
#
# [1159 rows x 2 columns]

# %%
test
# Out:
#              ds            y
# 1159 2017-08-09   922.900024
# 1160 2017-08-10   907.239990
# 1161 2017-08-11   914.390015
# 1162 2017-08-14   922.669983
# 1163 2017-08-15   922.219971
# ...         ...          ...
# 1254 2017-12-22  1060.119995
# 1255 2017-12-26  1056.739990
# 1256 2017-12-27  1049.369995
# 1257 2017-12-28  1048.140015
# 1258 2017-12-29  1046.400024
#
# [100 rows x 2 columns]

# %%
params = study.best_params

# %%
params["seasonality_mode"] = "additive"

# %%
model = Prophet(weekly_seasonality=True,
                daily_seasonality=False,
                **params)

model.fit(train)
forecast = model.make_future_dataframe(periods = 100, freq= "D")
predictions = model.predict(forecast)
preds = predictions[["ds", "yhat"]]
y_pred = preds.iloc[-100:, 1]
y_test = test.y

# %%
rmse(y_test, y_pred)
# Out:
# 38.21609081115923

# %%
model.plot(predictions, xlabel = "Date", ylabel= "Stock close price");

# %%
model.plot_components(predictions);
